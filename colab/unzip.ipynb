# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# !unzip path_to_file.zip -d path_to_directory

# %%
# !unzip drive/MyDrive/szlaban/plate_training/dataset/annotations_txt.zip -d drive/MyDrive/szlaban/plate_training/dataset/
# Out:
# Archive:  drive/MyDrive/szlaban/plate_training/dataset/annotations_txt.zip
#   inflating: drive/MyDrive/szlaban/plate_training/dataset/annotations_txt/Cars0.txt
#   inflating: drive/MyDrive/szlaban/plate_training/dataset/annotations_txt/Cars0_color_blurred_0.txt
#   inflating: drive/MyDrive/szlaban/plate_training/dataset/annotations_txt/Cars0_color_blurred_1.txt
#   inflating: drive/MyDrive/szlaban/plate_training/dataset/annotations_txt/Cars0_color_blurred_2.txt
#   inflating: drive/MyDrive/szlaban/plate_training/dataset/annotations_txt/Cars0_color_mixed_0.txt
#   inflating: drive/MyDrive/szlaban/plate_training/dataset/annotations_txt/Cars0_color_mixed_1.txt
#   inflating: drive/MyDrive/szlaban/plate_training/dataset/annotations_txt/Cars0_color_mixed_2.txt
#   inflating: drive/MyDrive/szlaban/plate_training/dataset/annotations_txt/Cars0_color_noisy_0.txt
#   inflating: drive/MyDrive/szlaban/plate_training/dataset/annotations_txt/Cars0_color_noisy_1.txt
# ...

# %%
# !ls drive/MyDrive/szlaban/plate_training/dataset
# Out:
# annotations_txt.zip  images   source.txt
# data_aug.py	     scripts  xml_annotations_big

# %%
# !ls drive/MyDrive/szlaban/plate_training/dataset | grep .zip

# %%
# !rm traced_model.pt
